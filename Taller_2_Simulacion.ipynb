# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ### **Universidad de Antioquia**
#
# ### **Facultad de Ingeniería**
#
# ### **Bioingeniería**
#
# ### **TEORÍA DE MODELOS Y SIMULACIÓN DE SISTEMAS**
#
# ---

# %% [markdown]
# # **Sesión 2: Simulación en Python**
#
# ## **Taller Práctico: Modelado y Simulación de Sistemas Dinámicos en Bioingeniería**
#
# **Semestre:** 2026 - 2
#
# **Nombre:**
#
# **Documento:**
#
# ---
#
# ### **Objetivos**
#
# * Aplicar los conceptos de modelado de sistemas dinámicos en Python (scipy.integrate y scipy.signal) a un caso simulado de Bioingeniería.
#
# * Implementar la solución de un sistema mediante dos metodologías diferentes (ecuaciones diferenciales y función de transferencia) y comparar sus resultados.
#
# * Construir funciones que integren la definición de entradas variables en el tiempo, la solución numérica del sistema y la representación gráfica de los resultados.
#
# * Incorporar parámetros y señales de entrada externas (archivos .txt) dentro del proceso de simulación.
#
# * Interpretar los resultados obtenidos en el contexto de una aplicación biomédica real.
#
# ---

# %% [markdown]
# ## **Ejercicio Propuesto**
#
# ### *Mecánica Respiratoria (Modelo de un compartimento)*
#
# Considere un paciente bajo ventilación mecánica, modelado como un sistema de un solo compartimiento, en el que el ventilador aplica una presión en la vía aérea P(t) que debe vencer la inertancia, la resistencia y la elastancia del sistema respiratorio para generar un volumen pulmonar V(t). La ecuación de movimiento del sistema es:
#
# ![image.png](data:image/png;base64,...)
#
# Donde:
#
# * **I:** Inertancia del sistema respiratorio (cmH₂O·s²/L)
#
# * **R:** Resistencia de la vía aérea (cmH₂O·s/L)
#
# * **C:** Distensibilidad (compliance) pulmonar (L/cmH₂O)
#
# * **V(t):** Volumen pulmonar (L)
#
# * **P(t):** Presión aplicada por el ventilador (cmH₂O)
#
# ### **Constantes:**
#
# * **I =** 0.02
#
# * **R =** 3.5
#
# * **C =** 0.04
#
# * Condiciones iniciales **iguales a cero**.
#
# * **Tiempo total de simulación:** 20 s.
#
# ![image.png](data:image/png;base64,...)
#
# ---

# %% [markdown]
# ### **Importación de Librerías**

# %%
# Importe aquí las librerías necesarias para la solución del ejercicio.

# %% [markdown]
# ---
#
# Se pide:
#
# **A.** Obtenga la función de transferencia del sistema (Volumen/Presión).

# %% [markdown]
# **Inserte aquí el procedimiento correspondiente**

# %% [markdown]
# **B.** Cree el modelo en Python de dos formas diferentes (ecuaciones diferenciales y función de transferencia), asumiendo que la presión aplicada es un escalón de magnitud 15 cmH₂O aplicado entre t=0 y t=1.5 s. Compare ambas soluciones en una sola gráfica.

# %% [markdown]
# **Inserte aquí el procedimiento correspondiente**

# %%
# Inserte aquí la solución del ejercicio propuesto.

# %% [markdown]
# **C.** Encuentre la gráfica de volumen, pero ahora ingresando las constantes desde el archivo parametros_t2.txt.

# %%
# Inserte aquí la solución del ejercicio propuesto.

# %% [markdown]
# **D.** Guarde la respuesta anterior como una imagen.

# %%
# Inserte aquí la solución del ejercicio propuesto.

# %% [markdown]
# **E.** Modifique el modelo para que la presión P(t) sea cargada desde el archivo entrada_t2.txt (señal de presión inspiratoria real del ventilador) y utilizada en la función de simulación.

# %%
# Inserte aquí la solución del ejercicio propuesto.
